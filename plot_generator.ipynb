# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Universidad/Publicaciones/2024/waf/ARI_DATA/data_for_analysis/filtered_data.csv')

# %%
currently_plotting = 'avg_distance'

# %%
fig, ax = plt.subplots()
df.boxplot(by ='shepherd', column =[currently_plotting], ax=ax)
# Out:
# <Axes: title={'center': 'avg_distance'}, xlabel='shepherd'>

# %%
fig.savefig(f'/content/drive/MyDrive/Universidad/Publicaciones/2024/waf/ARI_DATA/data_for_analysis/plots/{currently_plotting}.png', dpi = 150)
